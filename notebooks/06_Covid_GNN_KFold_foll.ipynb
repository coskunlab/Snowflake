# %%
import os
import sys
from pathlib import Path

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import skimage.io

from collections import defaultdict
from tqdm.auto import tqdm
from joblib import Parallel, delayed
import re
import h5py
import napari
import tifffile as tiff
import seaborn as sns
import pickle

import networkx as nx
from sklearn.model_selection import train_test_split

# %%
import torch_geometric.utils
import torch

# %%
# %load_ext autoreload
# %autoreload 2

# %%
p_dir = (Path().cwd().parents[0]).absolute()

module_path = str(p_dir / "src")

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
data_dir = (Path().cwd().parents[0] / 'data').absolute()

# %%
import graph
import torch
import torch_geometric.utils
import networkx as nx
import lightning.pytorch as pl
import torch.utils.data as data

spatial_omics_folder = (Path().cwd().parents[0]).absolute() / 'data' / 'spatial_omics_graph'
process_path = (Path().cwd().parents[0]).absolute() / 'data' / 'torch_graph_data'

# %% [markdown]
# # Create data loader

# %%
from torch_geometric.loader import DataLoader
seed = torch.Generator().manual_seed(42)

name = 'NIH'

# Crate dataset
dataset = graph.GraphDataset(process_path / name, process_path / name / 'info.csv', 2, y_name='covid')

train_set, val_set, test_set = graph.train_test_val_split(dataset)

# Create Dataloader
train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=True)
test_loader = DataLoader(test_set, batch_size=32, shuffle=False)

# %%
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.nc}')
# Out:
# Dataset: GraphDataset(442):
# ======================
# Number of graphs: 442
# Number of features: 5
# Number of classes: 2

# %%
print(f'Train set: {len(train_set)}, val set: {len(test_set)}, test set: {len(val_set)}')
# Out:
# Train set: 213, val set: 176, test set: 53

# %%
for step, data in enumerate(test_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()
    data.label
    break
# Out:
# Step 1:
# =======
# Number of graphs in the current batch: 32
# DataBatch(edge_index=[2, 910084], num_nodes=130790, x=[130790, 5], pos=[130790, 2], node_types=[130790], label=[32], covid=[32], train_mask=[130790], test_mask=[130790], y=[32], name=[32], batch=[130790], ptr=[33])

# %% [markdown]
# # Train network K Fold

# %%
from lightning.pytorch.accelerators import find_usable_cuda_devices
import wandb

# %%
from sklearn.model_selection import KFold, StratifiedKFold, ShuffleSplit, StratifiedShuffleSplit
from torch.utils.data import SubsetRandomSampler

# %%
# # Print K fold model number of samples and number of positive cases

# k_folds = 5
# kfold = KFold(n_splits=k_folds, shuffle=True, random_state=42)

# for fold, (train_ids, valid_ids) in enumerate(kfold.split(dataset)):
#     train_subset = dataset.index_select(train_ids.tolist())
#     val_subset = dataset.index_select(valid_ids.tolist())
    
#     train_loader = DataLoader(train_subset, batch_size=32, shuffle=True)
#     val_loader = DataLoader(val_subset, batch_size=32, shuffle=False)
    
#     train_positives = 0
#     test_positives = 0
#     for step, data in enumerate(train_loader):
#         train_positives += np.sum(data.y.numpy())
#     for step, data in enumerate(val_loader):
#         test_positives += np.sum(data.y.numpy())
        
#     print(len(train_subset), train_positives, len(val_subset), test_positives)

# %%
condition = '082423_Covid'
checkpoint_folder = (Path().cwd().parents[0]).absolute() / 'data' / "saved_models" / f"Graph_GNNs_{condition}" 
project_name = f'SF_{condition}'

# %%
AVAIL_GPUS = [1]

# Setting the seed
pl.seed_everything(42)

NUM_LAYERS = 2
HIDDEN_CHANNELS = 16
pools = ['mean', 'max', 'attention', 'attention2']
# pools = ['attention2']
models = ['GCN', 'GraphConv', 'GAT', 'GINConv', 'SAGEConv']
epochs = 100
# Out:
# Global seed set to 42

# %%
ys = [data.y.item() for data in dataset]

# %%
# Print K fold model number of samples and number of positive cases

k_folds = 5
# kfold = KFold(n_splits=k_folds, shuffle=True, random_state=42)
kfold = StratifiedShuffleSplit(n_splits=k_folds, test_size=0.3, random_state=0)

for fold, (train_ids, valid_ids) in enumerate(kfold.split(dataset, ys)):
    train_subset = dataset.index_select(train_ids.tolist())
    val_subset = dataset.index_select(valid_ids.tolist())
    
    for pool in pools:
        for model in models:
            if model == 'GAT':
                batch_size=64
            else:
                batch_size=128
            # Path to the folder where the pretrained models are saved
            CHECKPOINT_PATH = checkpoint_folder / f'{model}_{NUM_LAYERS}_{HIDDEN_CHANNELS}_{fold}' / pool
            CHECKPOINT_PATH.mkdir(parents=True, exist_ok=True)

            # Skip already trained kfold and pool
            checkpoint = CHECKPOINT_PATH / f"GraphLevel{model}" / f"GraphLevel{model}.ckpt" 
            if checkpoint.exists():
                print(checkpoint)
                continue

            # Run training
            run = wandb.init(project=project_name, name=f'{model}_{NUM_LAYERS}_{HIDDEN_CHANNELS}_{fold}', 
                            group=f'{model}_{pool}')
            graph.train_graph_classifier_kfold(model, 
                                                 train_subset, 
                                                 val_subset, 
                                                 dataset, 
                                                 CHECKPOINT_PATH, 
                                                 AVAIL_GPUS, 
                                                 hidden_channels=HIDDEN_CHANNELS, 
                                                 num_layers=NUM_LAYERS, 
                                                 epochs=epochs,
                                                 batch_size=batch_size,
                                                 graph_pooling=pool)
            run.finish()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: thoomas. Use `wandb login --relogin` to force relogin
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016666666666666666, max=1.0…
# wandb version 0.15.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>Y:\coskun-lab\Thomas\11_snowflakes\notebooks\wandb\run-20230824_232612-q37mfa4j</code>
# Syncing run <strong><a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/q37mfa4j' target="_blank">GCN_2_16_0</a></strong> to <a href='https://wandb.ai/thoomas/SF_082423_Covid' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/thoomas/SF_082423_Covid' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid</a>
#  View run at <a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/q37mfa4j' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid/runs/q37mfa4j</a>
# Global seed set to 42
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\pytorch_lightning\loggers\wandb.py:395: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Global seed set to 42
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#    | Name        | Type             | Params
# --------------------------------------------------
# 0  | model       | GNNModel         | 400
# 1  | fnn_layer   | Linear           | 272
# 2  | selu        | SELU             | 0
# 3  | head        | Linear           | 34
# 4  | loss_module | CrossEntropyLoss | 0
# 5  | train_acc   | BinaryAccuracy   | 0
# 6  | train_auroc | BinaryAUROC      | 0
# 7  | train_f1    | BinaryF1Score    | 0
# 8  | valid_acc   | BinaryAccuracy   | 0
# 9  | valid_auroc | BinaryAUROC      | 0
# 10 | valid_f1    | BinaryF1Score    | 0
# --------------------------------------------------
# 706       Trainable params
# 0         Non-trainable params
# 706       Total params
# 0.003     Total estimated model params size (MB)
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:478: PossibleUserWarning: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
#   rank_zero_warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:430: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 48 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\utilities\data.py:77: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:430: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 48 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\loops\fit_loop.py:280: PossibleUserWarning: The number of training batches (3) is smaller than the logging interval Trainer(log_every_n_steps=10). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>lr-Adam</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_acc</td><td>▁▅▅▅▆▇▇▇▇▇▇▇▇▇▇█▇▇█████████████████████▇</td></tr><tr><td>train_auc</td><td>▁▆▆▆▇▇▇▇▇▇██████████████████████████████</td></tr><tr><td>train_f1</td><td>▁▅▆▆▇▇▇▇▇▇▇▇▇▇██▇██████████████████████▇</td></tr><tr><td>train_loss_epoch</td><td>█▆▅▄▃▃▃▂▂▂▂▃▂▂▂▁▂▂▂▂▂▁▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▂▂</td></tr><tr><td>train_loss_step</td><td>█▇▇▅▅▃▄▃▄▂▄▂▅▄▃▃▃▄▃▃▁▃▄▄▂▂▁▃▃▄</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▁▂▂▂▃▃▃▃▃▃▄▄▄▄▅▃▄▄▅▅▆▄▄▄▆▇▇▅▅▅███▆▆▆</td></tr><tr><td>val_acc</td><td>▁▃▃▅▆▆▇▇▇▇▇▆▇█▇▇▇▇▇▇▇▇▇▇▇█▇▆▇▇▇██▇▇█▇▇▇▇</td></tr><tr><td>val_auc</td><td>▁▃▄▅▇▇████████▇▇█▇▇▇█▇▇▇▇█▇▇▇▇▇▇▇█▇▇▇▇▇▇</td></tr><tr><td>val_f1</td><td>▁▄▄▆▆▇▇▇▇▇▇▆▇█▇▇▇▇▇▇▇▇▇▇▇█▇▆▇▇▇█▇▇▇█▇▇▆▇</td></tr><tr><td>val_loss_epoch</td><td>▆▇▇▆▆▅▅▃▅▅▆▆▄▅▇▆█▇▂▄▆▃▁▄▃▃▇▂▁▃▃▃▂▆▂▃▁▄▄█</td></tr><tr><td>val_loss_step</td><td>▅▆▆▅▆▄▅▃▅▄▆▅▄▅▇▆█▇▂▄▅▃▁▄▃▃▆▁▁▃▃▃▂▆▁▃▁▃▃█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>lr-Adam</td><td>0.005</td></tr><tr><td>train_acc</td><td>0.8123</td></tr><tr><td>train_auc</td><td>0.82178</td></tr><tr><td>train_f1</td><td>0.85644</td></tr><tr><td>train_loss_epoch</td><td>0.50424</td></tr><tr><td>train_loss_step</td><td>0.51977</td></tr><tr><td>trainer/global_step</td><td>299</td></tr><tr><td>val_acc</td><td>0.71429</td></tr><tr><td>val_auc</td><td>0.69679</td></tr><tr><td>val_f1</td><td>0.77108</td></tr><tr><td>val_loss_epoch</td><td>0.76013</td></tr><tr><td>val_loss_step</td><td>0.94446</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">GCN_2_16_0</strong> at: <a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/q37mfa4j' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid/runs/q37mfa4j</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230824_232612-q37mfa4j\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016916666666656966, max=1.0…
# wandb version 0.15.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>Y:\coskun-lab\Thomas\11_snowflakes\notebooks\wandb\run-20230824_235531-b6mukche</code>
# Syncing run <strong><a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/b6mukche' target="_blank">GraphConv_2_16_0</a></strong> to <a href='https://wandb.ai/thoomas/SF_082423_Covid' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/thoomas/SF_082423_Covid' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid</a>
#  View run at <a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/b6mukche' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid/runs/b6mukche</a>
# Global seed set to 42
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\pytorch_lightning\loggers\wandb.py:395: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Global seed set to 42
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#    | Name        | Type             | Params
# --------------------------------------------------
# 0  | model       | GNNModel         | 736
# 1  | fnn_layer   | Linear           | 272
# 2  | selu        | SELU             | 0
# 3  | head        | Linear           | 34
# 4  | loss_module | CrossEntropyLoss | 0
# 5  | train_acc   | BinaryAccuracy   | 0
# 6  | train_auroc | BinaryAUROC      | 0
# 7  | train_f1    | BinaryF1Score    | 0
# 8  | valid_acc   | BinaryAccuracy   | 0
# 9  | valid_auroc | BinaryAUROC      | 0
# 10 | valid_f1    | BinaryF1Score    | 0
# --------------------------------------------------
# 1.0 K     Trainable params
# 0         Non-trainable params
# 1.0 K     Total params
# 0.004     Total estimated model params size (MB)
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:478: PossibleUserWarning: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
#   rank_zero_warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:430: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 48 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:430: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 48 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\loops\fit_loop.py:280: PossibleUserWarning: The number of training batches (3) is smaller than the logging interval Trainer(log_every_n_steps=10). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>lr-Adam</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_acc</td><td>▁▄▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇███████████████████████</td></tr><tr><td>train_auc</td><td>▁▆▇▇▇▇▇█████████████████████████████████</td></tr><tr><td>train_f1</td><td>▁▂▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇██▇▇███████████████████</td></tr><tr><td>train_loss_epoch</td><td>█▅▄▄▃▂▃▂▂▂▂▂▂▂▂▂▁▂▁▂▁▁▁▂▂▁▁▁▁▁▁▁▂▂▁▁▁▂▁▂</td></tr><tr><td>train_loss_step</td><td>█▆▆▄▄▇▄▃▅▂▃▁▂▄▆▂▃▆▄▄▁▂▂▂▁▃▃▂▂▆</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▁▂▂▂▃▃▃▃▃▃▄▄▄▄▅▃▄▄▅▅▆▄▄▄▆▇▇▅▅▅███▆▆▆</td></tr><tr><td>val_acc</td><td>▁▃▄▅▆▅▇▇▇▇▇█▇▇▇▇▇█▇▇█▇▇▇▇▇▇▇▇▇▇▇▇████▇▇█</td></tr><tr><td>val_auc</td><td>▁▅▆▆▇▇██▇▇▇▇▇▇▇▇▆▇▇▇▇▇▇▇▇▇█▇▇▇▇█████████</td></tr><tr><td>val_f1</td><td>▄▁▆▅▆▆▇▇█▇▇█▇▇▇▇███▇█▇█▇▇█▇▇▇▇█▇▇████▇▇█</td></tr><tr><td>val_loss_epoch</td><td>█▅▅▆▅▇▃▃▆▄▃▅▃▃▃▄▃▄▃▃▂▃▃▁▁▃▄▃▁▃▃▄▂▂▁▃▁▅▃▅</td></tr><tr><td>val_loss_step</td><td>█▅▆▇▅█▃▃▇▅▃▆▃▄▄▅▃▅▃▄▃▃▃▁▁▃▅▃▁▃▃▅▂▂▁▄▁▅▃▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>lr-Adam</td><td>0.005</td></tr><tr><td>train_acc</td><td>0.86408</td></tr><tr><td>train_auc</td><td>0.84523</td></tr><tr><td>train_f1</td><td>0.88889</td></tr><tr><td>train_loss_epoch</td><td>0.47574</td></tr><tr><td>train_loss_step</td><td>0.54865</td></tr><tr><td>trainer/global_step</td><td>299</td></tr><tr><td>val_acc</td><td>0.77444</td></tr><tr><td>val_auc</td><td>0.80032</td></tr><tr><td>val_f1</td><td>0.81481</td></tr><tr><td>val_loss_epoch</td><td>0.72136</td></tr><tr><td>val_loss_step</td><td>0.91324</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">GraphConv_2_16_0</strong> at: <a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/b6mukche' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid/runs/b6mukche</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230824_235531-b6mukche\logs</code>
# Y:\coskun-lab\Thomas\11_snowflakes\data\saved_models\Graph_GNNs_082423_Covid\GAT_2_16_0\mean\GraphLevelGAT\GraphLevelGAT.ckpt
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01693333333338766, max=1.0)…
# wandb version 0.15.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>Y:\coskun-lab\Thomas\11_snowflakes\notebooks\wandb\run-20230825_002614-nt6yv0ww</code>
# Syncing run <strong><a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/nt6yv0ww' target="_blank">GINConv_2_16_0</a></strong> to <a href='https://wandb.ai/thoomas/SF_082423_Covid' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/thoomas/SF_082423_Covid' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid</a>
#  View run at <a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/nt6yv0ww' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid/runs/nt6yv0ww</a>
# Global seed set to 42
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\pytorch_lightning\loggers\wandb.py:395: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Global seed set to 42
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#    | Name        | Type             | Params
# --------------------------------------------------
# 0  | model       | GIN              | 1.0 K
# 1  | fnn_layer   | Linear           | 272
# 2  | selu        | SELU             | 0
# 3  | head        | Linear           | 34
# 4  | loss_module | CrossEntropyLoss | 0
# 5  | train_acc   | BinaryAccuracy   | 0
# 6  | train_auroc | BinaryAUROC      | 0
# 7  | train_f1    | BinaryF1Score    | 0
# 8  | valid_acc   | BinaryAccuracy   | 0
# 9  | valid_auroc | BinaryAUROC      | 0
# 10 | valid_f1    | BinaryF1Score    | 0
td></tr><tr><td>trainer/global_step</td><td>299</td></tr><tr><td>val_acc</td><td>0.73684</td></tr><tr><td>val_auc</td><td>0.85526</td></tr><tr><td>val_f1</td><td>0.80226</td></tr><tr><td>val_loss_epoch</td><td>0.65038</td></tr><tr><td>val_loss_step</td><td>0.7532</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">GCN_2_16_0</strong> at: <a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/s8ndmf6v' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid/runs/s8ndmf6v</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230825_012549-s8ndmf6v\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016666666666666666, max=1.0…
# wandb version 0.15.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>Y:\coskun-lab\Thomas\11_snowflakes\notebooks\wandb\run-20230825_015507-f2galz45</code>
# Syncing run <strong><a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/f2galz45' target="_blank">GraphConv_2_16_0</a></strong> to <a href='https://wandb.ai/thoomas/SF_082423_Covid' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/thoomas/SF_082423_Covid' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid</a>
#  View run at <a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/f2galz45' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid/runs/f2galz45</a>
# Global seed set to 42
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\pytorch_lightning\loggers\wandb.py:395: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Global seed set to 42
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#    | Name        | Type             | Params
# --------------------------------------------------
# 0  | model       | GNNModel         | 736
# 1  | fnn_layer   | Linear           | 272
# 2  | selu        | SELU             | 0
# 3  | head        | Linear           | 34
# 4  | loss_module | CrossEntropyLoss | 0
# 5  | train_acc   | BinaryAccuracy   | 0
# 6  | train_auroc | BinaryAUROC      | 0
# 7  | train_f1    | BinaryF1Score    | 0
# 8  | valid_acc   | BinaryAccuracy   | 0
# 9  | valid_auroc | BinaryAUROC      | 0
# 10 | valid_f1    | BinaryF1Score    | 0
# --------------------------------------------------
# 1.0 K     Trainable params
# 0         Non-trainable params
# 1.0 K     Total params
# 0.004     Total estimated model params size (MB)
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:478: PossibleUserWarning: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
#   rank_zero_warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:430: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 48 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:430: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 48 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\loops\fit_loop.py:280: PossibleUserWarning: The number of training batches (3) is smaller than the logging interval Trainer(log_every_n_steps=10). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
# ...
# Find logs at: <code>.\wandb\run-20230826_055202-0jykuafy\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01693333333338766, max=1.0)…
# wandb version 0.15.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>Y:\coskun-lab\Thomas\11_snowflakes\notebooks\wandb\run-20230826_062026-2668u2xn</code>
# Syncing run <strong><a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/2668u2xn' target="_blank">GINConv_2_16_4</a></strong> to <a href='https://wandb.ai/thoomas/SF_082423_Covid' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/thoomas/SF_082423_Covid' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid</a>
#  View run at <a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/2668u2xn' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid/runs/2668u2xn</a>
# Global seed set to 42
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\pytorch_lightning\loggers\wandb.py:395: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Global seed set to 42
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#    | Name        | Type             | Params
# --------------------------------------------------
# 0  | model       | GIN              | 1.0 K
# 1  | fnn_layer   | Linear           | 272
# 2  | selu        | SELU             | 0
# 3  | head        | Linear           | 34
# 4  | loss_module | CrossEntropyLoss | 0
# 5  | train_acc   | BinaryAccuracy   | 0
# 6  | train_auroc | BinaryAUROC      | 0
# 7  | train_f1    | BinaryF1Score    | 0
# 8  | valid_acc   | BinaryAccuracy   | 0
# 9  | valid_auroc | BinaryAUROC      | 0
# 10 | valid_f1    | BinaryF1Score    | 0
# 11 | pool        | Attention_module | 281
# --------------------------------------------------
# 1.6 K     Trainable params
# 0         Non-trainable params
# 1.6 K     Total params
# 0.006     Total estimated model params size (MB)
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:478: PossibleUserWarning: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
#   rank_zero_warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:430: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 48 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:430: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 48 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\loops\fit_loop.py:280: PossibleUserWarning: The number of training batches (3) is smaller than the logging interval Trainer(log_every_n_steps=10). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>lr-Adam</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_acc</td><td>▁▂▅▅▆▆▆▆▇▆▆▇▇▇▇▇▇▇▇▇▇▇▇█▇█▇█▇███▇▇██▇███</td></tr><tr><td>train_auc</td><td>▁▅▆▆▇▇▇▇▇▇▇▇▇▇▇█▇▇███████▇██████████████</td></tr><tr><td>train_f1</td><td>▁▄▅▅▆▆▆▆▇▆▆▇▇▇▇▇▇▇▇▇▇▇▇█▇█▇█▇████▇▇█▇███</td></tr><tr><td>train_loss_epoch</td><td>█▇▅▅▄▃▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▂▁▂▁▂▁▂▁▁▁▂▂▁▂▂▁▁▂</td></tr><tr><td>train_loss_step</td><td>█▇▆▄▄▁▄▃▂▃▃▁▂▃▂▁▂▃▃▃▁▂▁▁▃▃▂▂▁▄</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▁▂▂▂▃▃▃▃▃▃▄▄▄▄▅▃▄▄▅▅▆▄▄▄▆▇▇▅▅▅███▆▆▆</td></tr><tr><td>val_acc</td><td>▁▁▇▇▆▇▇▇▇▇▆▆▅▇▆▇▆▇▅▇▇▇▇▆▇▇▇█▇▇▇▆▇▇██▇▇▇▆</td></tr><tr><td>val_auc</td><td>▁▅▇▇▇▇▇█▇█▆█▇▇▇█▇▇▇▇███▇█▇▇▇▇█▇▇█▇██▇▇█▇</td></tr><tr><td>val_f1</td><td>▁▁▇▆▅▆▆▆▆▆▄▅▁▇▅▇▄▇▁▆▅▇▆▅▆▆▇▇▆▆▇▄▅▇█▇▇▇▅▄</td></tr><tr><td>val_loss_epoch</td><td>█▅▄▄▁▃▃▁▄▃▄▃▄▂▄▁▄▅▃▄▁▁▂▃▂█▁▃▁▁▃▂▄▃▃▁▅▁▁▃</td></tr><tr><td>val_loss_step</td><td>▆▃▃▄▁▃▃▁▄▃▃▃▃▂▃▁▃▅▃▄▁▁▂▃▂█▁▃▁▁▄▂▄▃▃▁▅▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>lr-Adam</td><td>0.005</td></tr><tr><td>train_acc</td><td>0.90939</td></tr><tr><td>train_auc</td><td>0.95425</td></tr><tr><td>train_f1</td><td>0.92391</td></tr><tr><td>train_loss_epoch</td><td>0.41663</td></tr><tr><td>train_loss_step</td><td>0.48434</td></tr><tr><td>trainer/global_step</td><td>299</td></tr><tr><td>val_acc</td><td>0.78947</td></tr><tr><td>val_auc</td><td>0.90166</td></tr><tr><td>val_f1</td><td>0.80282</td></tr><tr><td>val_loss_epoch</td><td>0.47688</td></tr><tr><td>val_loss_step</td><td>0.44576</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">GINConv_2_16_4</strong> at: <a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/2668u2xn' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid/runs/2668u2xn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230826_062026-2668u2xn\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016916666666899498, max=1.0…
# wandb version 0.15.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>Y:\coskun-lab\Thomas\11_snowflakes\notebooks\wandb\run-20230826_063813-mr4c4v6v</code>
# Syncing run <strong><a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/mr4c4v6v' target="_blank">SAGEConv_2_16_4</a></strong> to <a href='https://wandb.ai/thoomas/SF_082423_Covid' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/thoomas/SF_082423_Covid' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid</a>
#  View run at <a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/mr4c4v6v' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid/runs/mr4c4v6v</a>
# Global seed set to 42
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\pytorch_lightning\loggers\wandb.py:395: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Global seed set to 42
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#    | Name        | Type             | Params
# --------------------------------------------------
# 0  | model       | GNNModel         | 736
# 1  | fnn_layer   | Linear           | 272
# 2  | selu        | SELU             | 0
# 3  | head        | Linear           | 34
# 4  | loss_module | CrossEntropyLoss | 0
# 5  | train_acc   | BinaryAccuracy   | 0
# 6  | train_auroc | BinaryAUROC      | 0
# 7  | train_f1    | BinaryF1Score    | 0
# 8  | valid_acc   | BinaryAccuracy   | 0
# 9  | valid_auroc | BinaryAUROC      | 0
# 10 | valid_f1    | BinaryF1Score    | 0
# 11 | pool        | Attention_module | 281
# --------------------------------------------------
# 1.3 K     Trainable params
# 0         Non-trainable params
# 1.3 K     Total params
# 0.005     Total estimated model params size (MB)
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:478: PossibleUserWarning: Your `val_dataloader`'s sampler has shuffling enabled, it is strongly recommended that you turn shuffling off for val/test dataloaders.
#   rank_zero_warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:430: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 48 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:430: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 48 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# C:\Users\thu71\AppData\Roaming\Python\Python39\site-packages\lightning\pytorch\loops\fit_loop.py:280: PossibleUserWarning: The number of training batches (3) is smaller than the logging interval Trainer(log_every_n_steps=10). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# C:\Users\thu71\Anaconda3\envs\snowflake\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: No negative samples in targets, false positive value should be meaningless. Returning zero tensor in false positive score
#   warnings.warn(*args, **kwargs)
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>lr-Adam</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_acc</td><td>▁▄▄▅▅▆▆▅▆▆▆▆▇▆▇▇▇▇▇▇▇▇▇▇▇▇▇███▇█████████</td></tr><tr><td>train_auc</td><td>▁▃▄▄▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇██▇████████████████</td></tr><tr><td>train_f1</td><td>▁▄▄▅▅▆▆▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇███▇█████████</td></tr><tr><td>train_loss_epoch</td><td>█▇▆▆▅▄▄▅▄▄▄▄▃▃▃▃▃▂▃▂▂▂▂▂▂▂▂▂▁▁▂▁▁▁▂▂▁▁▁▁</td></tr><tr><td>train_loss_step</td><td>█▆▆▅▅▅▄▄▃▄▃▂▃▃▁▃▂▃▂▃▁▂▂▃▂▂▁▂▁▂</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▁▂▂▂▃▃▃▃▃▃▄▄▄▄▅▃▄▄▅▅▆▄▄▄▆▇▇▅▅▅███▆▆▆</td></tr><tr><td>val_acc</td><td>▁▄▄▅▆▆▆▇▇▅▇▇█▇▇███████▇▇██▇▇▇▇▇▆▇▇▇██▇██</td></tr><tr><td>val_auc</td><td>▁▃▃▄▄▅▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇█████████▇████</td></tr><tr><td>val_f1</td><td>▁▂▃▄▅▆▅▆▇▃▆▇▇▇▆▇▇▇▇▇█▇▇▆██▇▇▇▇▇▆▇▇▇▇█▇██</td></tr><tr><td>val_loss_epoch</td><td>██▆▆▅▃▆▄▄▄▂▁▃▂▃▃▅▃▆▃▁▁▂▆▁▅▂▁▃▁▁▂▃▁▁▃▂▁▃▂</td></tr><tr><td>val_loss_step</td><td>▇█▅▆▆▃▇▄▄▄▂▁▄▂▃▄▆▄█▄▁▁▁█▁▆▃▁▄▁▁▁▃▁▁▄▂▁▄▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>lr-Adam</td><td>0.005</td></tr><tr><td>train_acc</td><td>0.88997</td></tr><tr><td>train_auc</td><td>0.95044</td></tr><tr><td>train_f1</td><td>0.90811</td></tr><tr><td>train_loss_epoch</td><td>0.413</td></tr><tr><td>train_loss_step</td><td>0.40802</td></tr><tr><td>trainer/global_step</td><td>299</td></tr><tr><td>val_acc</td><td>0.86466</td></tr><tr><td>val_auc</td><td>0.94968</td></tr><tr><td>val_f1</td><td>0.89412</td></tr><tr><td>val_loss_epoch</td><td>0.40187</td></tr><tr><td>val_loss_step</td><td>0.35367</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SAGEConv_2_16_4</strong> at: <a href='https://wandb.ai/thoomas/SF_082423_Covid/runs/mr4c4v6v' target="_blank">https://wandb.ai/thoomas/SF_082423_Covid/runs/mr4c4v6v</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230826_063813-mr4c4v6v\logs</code>
